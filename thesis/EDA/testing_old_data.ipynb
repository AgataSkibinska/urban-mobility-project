# %%
import pandas as pd

# %%
data_dist = pd.read_csv("/home/agata/urban-mobility-project/data/processed/mc/decision_tree/data_dist.csv")
data_dist
# Out:
#        Unnamed: 0  \
# 0               0
# 1               1
# 2               5
# 3               6
# 4               7
# ...           ...
# 10069       14192
# 10070       14204
# 10071       14211
# 10072       14238
# 10073       14239
#
#        Jak Pan/Pani ocenia wygodę jazdy pojazdami komunikacji zbiorowej?  \
# 0                                                      4
# 1                                                      4
# 2                                                      4
# 3                                                      4
# 4                                                      4
# ...                                                  ...
# 10069                                                  2
# 10070                                                  2
# 10071                                                  1
# 10072                                                  3
# 10073                                                  3
#
# ...

# %%
 pd.read_csv("/home/agata/urban-mobility-project/data/processed/mc/decision_tree/data.csv")
# Out:
#        Unnamed: 0  \
# 0               0
# 1               1
# 2               5
# 3               6
# 4               7
# ...           ...
# 10558       14192
# 10559       14204
# 10560       14211
# 10561       14238
# 10562       14239
#
#        Jak Pan/Pani ocenia wygodę jazdy pojazdami komunikacji zbiorowej?  \
# 0                                                      4
# 1                                                      4
# 2                                                      4
# 3                                                      4
# 4                                                      4
# ...                                                  ...
# 10558                                                  2
# 10559                                                  2
# 10560                                                  1
# 10561                                                  3
# 10562                                                  3
#
# ...
