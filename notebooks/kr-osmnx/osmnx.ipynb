# %%
import osmnx as ox
import pandas as pd
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
pd.options.display.max_columns = None

# %%
ox.settings.timeout = 360
ox.settings.timeout
# Out:
# 360

# %%
tags = {'building': True}

# %%
gdf = ox.geometries_from_place('Wrocław', tags)

# %%
len(gdf.columns)
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 338

# %%
gdf.shape
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (155875, 338)

# %%
gdf.iloc[10:20]
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       NaN       NaN
# 14  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
# 15  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
# 16  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
# 17  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
# 18  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
# 19  NaN      NaN                  NaN    NaN   NaN          NaN       NaN
#
#    country diplomatic official_name:de contact:facebook roof:min_height  \
# ...

# %%
gdf['element_type'].unique()
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['node', 'way', 'relation'], dtype=object)

# %%
# gdf = gdf[gdf['element_type'] == 'node']

# %%
gdf['building'].unique()
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['yes', 'commercial', 'entrance', 'semidetached_house',
#        'residential', 'apartments', 'garage', 'house', 'roof', 'detached',
#        'greenhouse', 'stable', 'hotel', 'collapsed', 'office',
#        'farm_auxiliary', 'retail', 'garages', 'warehouse', 'church',
#        'school', 'carport', 'kindergarten', 'grandstand', 'shed',
#        'service', 'transformer_tower', 'terrace', 'construction',
#        'government', 'chapel', 'water_tower', 'industrial', 'riding_hall',
#        'pedestal', 'train_station', 'waste', 'ruins', 'hospital',
# ...

# %%
gdf[gdf['building'] == 'kindergarten'].shape
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (90, 338)

# %%
gdf_proj = ox.project_gdf(gdf[gdf['building'] == 'university'])
fig, ax = ox.plot_footprints(gdf_proj, dpi=400, save=False, show=True, close=True)
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
gdf['building'].value_counts().to_dict()
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'yes': 143701,
#  'apartments': 2810,
#  'garage': 1656,
#  'residential': 1649,
#  'house': 952,
#  'roof': 638,
#  'construction': 597,
#  'retail': 529,
#  'shed': 396,
#  'commercial': 309,
#  'terrace': 282,
#  'school': 229,
#  'garages': 202,
#  'greenhouse': 190,
#  'office': 181,
#  'semidetached_house': 172,
#  'service': 171,
#  'university': 169,
#  'industrial': 114,
#  'church': 112,
#  'kindergarten': 90,
#  'detached': 89,
#  'warehouse': 78,
#  'kiosk': 52,
#  'hotel': 43,
#  'hut': 35,
#  'dormitory': 35,
#  'government': 33,
#  'collapsed': 29,
#  'civic': 27,
# ...

# %%
gdf[gdf['building'] == 'yes']
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 860     NaN         NaN        NaN          NaN             NaN    NaN
# 155864     NaN         NaN        NaN          NaN             NaN    NaN
# 155872     NaN         NaN        NaN          NaN             NaN    NaN
# 155873     NaN         NaN        NaN          NaN             NaN    NaN
#
#        generator:method generator:output:electricity generator:source  \
# 0                   NaN                          NaN              NaN
# 1                   NaN                          NaN              NaN
# 3                   NaN                          NaN              NaN
# ...

# %%
gdf[gdf['building'] == 'yes']['amenity'].value_counts().to_dict()
# Out:
# /home/kornel/Projects/urban-mobility-project/mobility_venv/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {'shelter': 173,
#  'waste_disposal': 121,
#  'car_wash': 23,
#  'university': 18,
#  'doctors': 17,
#  'toilets': 13,
#  'kindergarten': 12,
#  'parking': 10,
#  'police': 6,
#  'fuel': 6,
#  'clinic': 5,
#  'social_facility': 4,
#  'library': 4,
#  'veterinary': 3,
#  'monastery': 3,
#  'fountain': 3,
#  'restaurant': 3,
#  'recycling': 3,
#  'parking_entrance': 3,
#  'post_office': 3,
#  'arts_centre': 2,
#  'vehicle_inspection': 2,
#  'community_centre': 2,
#  'fast_food': 2,
#  'waste_basket': 2,
#  'bicycle_parking': 2,
#  'cafe': 2,
#  'townhall': 2,
#  'ice_cream': 1,
# ...
